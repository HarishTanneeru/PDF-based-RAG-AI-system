# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5.4-nano-2026-03-17",
    input="Tell me about deloitte company."
)

print(response.output_text)
# Out:
# Deloitte (often stylized **Deloitte** and part of **Deloitte Touche Tohmatsu Limited**, “DTTL”) is one of the world’s largest professional services firms. It provides services across **audit and assurance**, **tax**, **consulting**, **financial advisory**, and **risk/cyber**.
#
# ### What Deloitte does
# - **Audit & Assurance:** Independent audits of financial statements and related assurance services.
# - **Tax:** Compliance, planning, and cross-border tax advisory.
# - **Consulting:** Strategy, operations, technology (including digital transformation), and human capital services.
# - **Advisory / Risk:** Deals and corporate finance support, restructuring, forensic and dispute services, risk management, and cybersecurity.
#
# ### How it’s organized
# - Deloitte is a **global network** rather than a single unified company in every country.
# - It operates through member firms in many countries under the umbrella of **DTTL**.
#
# ### Where it operates
# - Deloitte has a strong presence worldwide, serving governments, large enterprises, mid-market companies, and many public-interest organizations.
#
# ### Reputation and scale
# - Deloitte is known for being one of the “Big Four” firms globally (along with PwC, EY, and KPMG).
# - It’s widely recognized for deep industry expertise and large-scale consulting and audit engagements.
#
# If you tell me what you mean by “about” (e.g., history, headquarters, services in a specific country, careers, or financial performance), I can tailor the answer.

# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI_API_KEY is set.")
if os.environ.get("GEMINI_API_KEY"):
    print("GEMINI_API_KEY is set.")
# Out:
# OPENAI_API_KEY is set.
